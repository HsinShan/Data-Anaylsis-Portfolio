# %% [markdown]
# <font size='5'>期末報告</font><br>

# %%
import numpy as np
import pandas as pd
import calendar

# %%
train = pd.read_csv('train.csv', engine='python',index_col="ID")
test = pd.read_csv('test.csv', engine='python',index_col="ID")
train_label = pd.read_csv('train_label.csv', engine='python')
test_nolabel = pd.read_csv('test_nolabel.csv', engine='python')

# %%
train
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# ID
# 0      Resort Hotel            0        342               2015
# 1        City Hotel            0        257               2015
# 2        City Hotel            0        257               2015
# 3        City Hotel            0        257               2015
# 4        City Hotel            0        257               2015
# ...             ...          ...        ...                ...
# 91526  Resort Hotel            1         19               2017
# 91527  Resort Hotel            0         28               2017
# 91528  Resort Hotel            0          2               2017
# 91529  Resort Hotel            0         30               2017
# 91530  Resort Hotel            0          1               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# ID
# 0                   July                        27                          1
# ...

# %%
train[["arrival_date_year","arrival_date_month","arrival_date_day_of_month"]]
# Out:
#        arrival_date_year arrival_date_month  arrival_date_day_of_month
# ID
# 0                   2015               July                          1
# 1                   2015               July                          1
# 2                   2015               July                          1
# 3                   2015               July                          1
# 4                   2015               July                          1
# ...                  ...                ...                        ...
# 91526               2017              March                         31
# 91527               2017              March                         31
# 91528               2017              March                         31
# 91529               2017              March                         31
# 91530               2017              March                         31
#
# [91531 rows x 3 columns]

# %%
date_group=train.groupby(["arrival_date_year","arrival_date_month","arrival_date_day_of_month"])

# %%
a=train[["arrival_date_year","arrival_date_month","arrival_date_day_of_month"]].drop_duplicates()

# %% [markdown]
# 資料從2015/7/1~2017/3/31

# %%
for i in range(len(a)):
    print(a.iloc[i])
# Out:
# arrival_date_year            2015
# arrival_date_month           July
# arrival_date_day_of_month       1
# Name: 0, dtype: object
# arrival_date_year            2015
# arrival_date_month           July
# arrival_date_day_of_month       2
# Name: 122, dtype: object
# arrival_date_year            2015
# arrival_date_month           July
# arrival_date_day_of_month       3
# Name: 215, dtype: object
# arrival_date_year            2015
# arrival_date_month           July
# arrival_date_day_of_month       4
# Name: 271, dtype: object
# arrival_date_year            2015
# arrival_date_month           July
# arrival_date_day_of_month       5
# Name: 359, dtype: object
# arrival_date_year            2015
# arrival_date_month           July
# arrival_date_day_of_month       6
# Name: 412, dtype: object
# arrival_date_year            2015
# arrival_date_month           July
# arrival_date_day_of_month       7
# Name: 487, dtype: object
# arrival_date_year            2015
# ...

# %%
date_group.get_group((2015, 'August', 1))
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# ID
# 2776  Resort Hotel            0        211               2015
# 2777  Resort Hotel            0        177               2015
# 2778  Resort Hotel            0         67               2015
# 2779  Resort Hotel            0        129               2015
# 2780  Resort Hotel            0        105               2015
# ...            ...          ...        ...                ...
# 2881    City Hotel            1        117               2015
# 2882    City Hotel            1          2               2015
# 2883    City Hotel            0        117               2015
# 2884    City Hotel            1        117               2015
# 2885  Resort Hotel            1        256               2015
#
#      arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# ID
# 2776             August                        31                          1
# ...

# %%
print (date_group.groups)
# Out:
# {(2015, 'August', 1): [2776, 2777, 2778, 2779, 2780, 2781, 2782, 2783, 2784, 2785, 2786, 2787, 2788, 2789, 2790, 2791, 2792, 2793, 2794, 2795, 2796, 2797, 2798, 2799, 2800, 2801, 2802, 2803, 2804, 2805, 2806, 2807, 2808, 2809, 2810, 2811, 2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 2820, 2821, 2822, 2823, 2824, 2825, 2826, 2827, 2828, 2829, 2830, 2831, 2832, 2833, 2834, 2835, 2836, 2837, 2838, 2839, 2840, 2841, 2842, 2843, 2844, 2845, 2846, 2847, 2848, 2849, 2850, 2851, 2852, 2853, 2854, 2855, 2856, 2857, 2858, 2859, 2860, 2861, 2862, 2863, 2864, 2865, 2866, 2867, 2868, 2869, 2870, 2871, 2872, 2873, 2874, 2875, ...], (2015, 'August', 2): [2886, 2887, 2888, 2889, 2890, 2891, 2892, 2893, 2894, 2895, 2896, 2897, 2898, 2899, 2900, 2901, 2902, 2903, 2904, 2905, 2906, 2907, 2908, 2909, 2910, 2911, 2912, 2913, 2914, 2915, 2916, 2917, 2918, 2919, 2920, 2921, 2922, 2923, 2924, 2925, 2926, 2927, 2928, 2929, 2930, 2931, 2932, 2933, 2934, 2935], (2015, 'August', 3): [2936, 2937, 2938, 2939, 
# ...

# %%
for i in train.columns:
    print(i)
# Out:
# hotel
# is_canceled
# lead_time
# arrival_date_year
# arrival_date_month
# arrival_date_week_number
# arrival_date_day_of_month
# stays_in_weekend_nights
# stays_in_week_nights
# adults
# children
# babies
# meal
# country
# market_segment
# distribution_channel
# is_repeated_guest
# previous_cancellations
# previous_bookings_not_canceled
# reserved_room_type
# assigned_room_type
# booking_changes
# deposit_type
# agent
# company
# days_in_waiting_list
# customer_type
# adr
# required_car_parking_spaces
# total_of_special_requests
# reservation_status
# reservation_status_date

# %%
for i in test.columns:
    print(i)
# Out:
# hotel
# lead_time
# arrival_date_year
# arrival_date_month
# arrival_date_week_number
# arrival_date_day_of_month
# stays_in_weekend_nights
# stays_in_week_nights
# adults
# children
# babies
# meal
# country
# market_segment
# distribution_channel
# is_repeated_guest
# previous_cancellations
# previous_bookings_not_canceled
# reserved_room_type
# assigned_room_type
# booking_changes
# deposit_type
# agent
# company
# days_in_waiting_list
# customer_type
# required_car_parking_spaces
# total_of_special_requests

# %%
train.iloc[0]
# Out:
# hotel                             Resort Hotel
# is_canceled                                  0
# lead_time                                  342
# arrival_date_year                         2015
# arrival_date_month                        July
# arrival_date_week_number                    27
# arrival_date_day_of_month                    1
# stays_in_weekend_nights                      0
# stays_in_week_nights                         0
# adults                                       2
# children                                     0
# babies                                       0
# meal                                        BB
# country                                    PRT
# market_segment                          Direct
# distribution_channel                    Direct
# is_repeated_guest                            0
# previous_cancellations                       0
# previous_bookings_not_canceled               0
# reserved_room_type                           C
# ...

# %%
train.isna().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             468
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
test
# Out:
#                hotel  lead_time  arrival_date_year arrival_date_month  \
# ID
# 91531     City Hotel         75               2017              April
# 91532     City Hotel        208               2017              April
# 91533   Resort Hotel         12               2017              April
# 91534     City Hotel         76               2017              April
# 91535     City Hotel          9               2017              April
# ...              ...        ...                ...                ...
# 119385  Resort Hotel        108               2017             August
# 119386  Resort Hotel        194               2017             August
# 119387  Resort Hotel         17               2017             August
# 119388  Resort Hotel        191               2017             August
# 119389    City Hotel          3               2017             August
#
#         arrival_date_week_number  arrival_date_day_of_month  \
# ID
# ...

# %%
test.isna().sum()
# Out:
# hotel                                 0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              0
# babies                                0
# meal                                  0
# country                              20
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# agent                              3123
# ...

# %%
train_label
# Out:
#     arrival_date  label
# 0     2015-07-01    2.0
# 1     2015-07-02    1.0
# 2     2015-07-03    1.0
# 3     2015-07-04    1.0
# 4     2015-07-05    1.0
# ..           ...    ...
# 635   2017-03-27    2.0
# 636   2017-03-28    1.0
# 637   2017-03-29    2.0
# 638   2017-03-30    3.0
# 639   2017-03-31    3.0
#
# [640 rows x 2 columns]

# %%
test_nolabel
# Out:
#     arrival_date
# 0     2017-04-01
# 1     2017-04-02
# 2     2017-04-03
# 3     2017-04-04
# 4     2017-04-05
# ..           ...
# 148   2017-08-27
# 149   2017-08-28
# 150   2017-08-29
# 151   2017-08-30
# 152   2017-08-31
#
# [153 rows x 1 columns]
